# %%
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ##### 1. Use matplotlib to plot the following equation: y=x**2 - x + 2
# ##### You'll need to write the code that generates the x and y points.
#
# ##### Add an anotation for the point 0, 0, the origin.

# %%
x = list(range(10))
y = [n**2 - n + 2 for n in x]
plt.plot(x,y)
plt.annotate('origin', xy=(0,0), xytext = (0, 20), arrowprops={'arrowstyle':'->'})
plt.show()

# %% [markdown]
# ##### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %% [markdown]
# ##### 2.a y = sr(x)

# %%
y = [n**.5 for n in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### 2.b y = x**3

# %%
y = [n**3 for n in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### 2.c y = 2**x

# %%
y = [2**n for n in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### 2.d y = 1/(x + 1)

# %%
y = [1/(n+1) for n in x]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ##### 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(12,6))
x1 = list(range(0,10))
y1 = [n**.5 for n in x1]
plt.subplot(221)
plt.plot(x1,y1)

x2 = list(range(-10,10))
y2 = [n**3 for n in x2]
plt.subplot(222)
plt.plot(x2,y2)

x3 = list(range(0,10))
y3 = [2**n for n in x3]
plt.subplot(223)
plt.plot(x3,y3)

x4 = list(range(0,10))
y4 = [1/(n+1) for n in x4]
plt.subplot(224)
plt.plot(x4,y4)
plt.show()

# %% [markdown]
# ##### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(12,6))
plt.xlim(0,9)
plt.ylim(0,10)

y1 = [n**.5 for n in x]
plt.plot(x1,y1, label='$\sqrt{x}$')

y2 = [n**3 for n in x]
plt.plot(x2,y2, label = '$x^3$')

y3 = [2**n for n in x]
plt.plot(x3,y3, label = '$2^x$')

y4 = [1/(n+1) for n in x]
plt.plot(x4,y4, label = '$1/(x+1)$')


plt.title('Plotted Equations')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# #### 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# #####      a. Title your chart "Big O Notation"
# #####      b. Label your x axis "Elements"
# #####      c. Label your y axis "Operations"
# #####      d. Label your curves or make a legend for the curves
# #####      e. Use LaTex notation where possible
# #####      f. Curves to graph
# #####          y = 0n + 1 and label the curve "O1"
# #####          y = log(n) and lebel the curve 'O(log n)'
# #####          y = n and label the curve "O(n)"
# #####          y = n*log(n) and label it "O(n log n)"
# #####          y = n**2 and label it "O(n^2)"
# #####          y = 2**n and label it "O(2^n)"
# #####          y = n! and label it "O(n!)"
# #####          y = n**n and label it "O(n^n)"

# %%
# See big_o_notation.ipynb

# %% [markdown]
#  ##### 6. Bonus Write the code necessary to write your name on a chart. Use box letters.

# %%
plt.xlim(0,100)
plt.ylim(0,20)

#M
plt.vlines(5, 10, 15)
plt.vlines(20,10,15)
plt.hlines(15,5,11)
plt.hlines(15,14,20)

plt.vlines(8,10, 14)
plt.vlines(17,10,14)
plt.hlines(10,5,8)
plt.hlines(10,17,20)

plt.hlines(14,8,11)
plt.hlines(14,14,17)
plt.hlines(14.6,11,14)
plt.hlines(13,11,14)

plt.vlines(11,14.6,15)
plt.vlines(14,14.6,15)
plt.vlines(11,13,14)
plt.vlines(14,13,14)

#O
plt.vlines(25,10,15)
plt.vlines(35,10,15)
plt.hlines(15,25,35)
plt.hlines(10,25,35)

plt.vlines(28,11,14)
plt.vlines(32,11,14)
plt.hlines(11,28,32)
plt.hlines(14,28,32)

#R
plt.vlines(40,10,15)
plt.vlines(43,10,12)

plt.hlines(15,40,49)
plt.hlines(12,43,47)
plt.hlines(10,40,43)
plt.hlines(10,47,50)
plt.vlines(47,10,12)
plt.vlines(50,10,12.5)
plt.hlines(12.5,49,50)
plt.vlines(49,12.5,15)

plt.hlines(13,43,46)
plt.hlines(14,43,46)
plt.vlines(43,13,14)
plt.vlines(46,13,14)

#G
plt.vlines(55,10,15)
plt.vlines(65,10,12)
plt.hlines(15,55,65)
plt.hlines(10,55,65)

plt.vlines(65,14,15)
plt.hlines(14,58,65)
plt.vlines(58,14,11)
plt.hlines(11,58,62)
plt.hlines(12,60,65)
plt.vlines(60,11,12)

#A
plt.vlines(70,10,15)
plt.vlines(73,10,12)

plt.hlines(15,70,80)
plt.hlines(12,73,77)
plt.hlines(10,70,73)
plt.hlines(10,77,80)
plt.vlines(77,10,12)
plt.vlines(80,10,15)

plt.hlines(13,73,77)
plt.hlines(14,73,77)
plt.vlines(73,13,14)
plt.vlines(77,13,14)

#N
plt.vlines(85,10,15)
plt.vlines(95,10,15)
plt.hlines(15,85,90)
plt.hlines(15,93,95)
plt.vlines(90,14,15)

plt.vlines(87,10,14)
plt.vlines(93,11,15)
plt.hlines(14,87,88.5)
plt.hlines(11,91.5,93)

plt.hlines(10,85,87)
plt.hlines(10,90,95)
plt.vlines(90,10,11)

#center of N
plt.vlines(88.5,12.5,14)
plt.vlines(90.5,12.5,14)

plt.vlines(89.5,11,12.5)
plt.vlines(91.5,11,12.5)

plt.show()

# %% [markdown]
# ##### 7. Bonus: use curves for letters in your name that have curves in them.

# %%
xm1 = [7.5, 15]
ym1 = [n for n in xm1]
plt.plot(xm1, ym1)
plt.ylim(0,20)
plt.xlim(0,100)

xm2 = [19, 15]
ym2 = [(n-30)*-1 for n in xm2]
plt.plot(xm2, ym2)
plt.ylim(0,20)

xm3 = [19, 23]
ym3 = [n-8 for n in xm3]
plt.plot(xm3, ym3)
plt.ylim(0,20)

xm2 = [30, 23]
ym2 = [(n-38)*-1 for n in xm2]
plt.plot(xm2, ym2)
plt.ylim(0,20)



plt.show()
